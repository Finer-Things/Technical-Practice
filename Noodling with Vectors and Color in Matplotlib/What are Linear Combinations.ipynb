# %%
import math
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

from mpl_toolkits.axisartist import SubplotZero

# %% [markdown]
# ## Setup

# %%
mpl.style.context("fivethirtyeight", after_reset=False)

vector_1 = [1,0]
vector_2 = [0,1]
rgb_1 = (0,0,1) #blue
rgb_2 = (1,0,0) #red

#This function should just take in weights and output a vector AND a color in the form of a plt.arrow line of code
def lc_arrow(x,y):
    if x == 0 and y == 0:
        return plt.arrow(x=0, y=0, dx=0, dy=0, width=.5, color = (0,0,0))
    tuple([item_1*x(x+y) + item_2*y/(x+y) for item_1, item_2 in zip(rgb_1, rgb_2)])
    return plt.arrow(x=0, y=0, dx=5*x, dy=5*y, width=.5, color = color)

#Function called "Linear Combination Color" return a color based on a weighted average of the original vector colors
def lc_color(x,y):
    if x == 0 and y == 0:
        (0,0,0)
    return tuple([item_1*x/(x+y) + item_2*y/(x+y) for item_1, item_2 in zip(rgb_1, rgb_2)])

lc_color(1,2)
# Out:
# (0.6666666666666666, 0.0, 0.3333333333333333)

# %% [markdown]
# ## Start with two vectors

# %%
plt.figure(figsize = (5,5))

if 1:
    fig = plt.figure(1)
    ax = SubplotZero(fig, 111)
    fig.add_subplot(ax)

    for direction in ["xzero", "yzero"]:
        ax.axis[direction].set_axisline_style("-|>")
        ax.axis[direction].set_visible(True)

    for direction in ["left", "right", "bottom", "top"]:
        ax.axis[direction].set_visible(False)

    #x = np.linspace(-0.5, 1., 100)
    #ax.plot(x, np.sin(x*np.pi))

plt.xlim([-1, 25])
plt.ylim([-1, 25])

# plt.arrow(x=0, y=0, dx=5, dy=0, width=.5, color = "blue") 
# plt.arrow(x=0, y=0, dx=0, dy=5, width=.5, color = "red") 

# plt.arrow(x=0, y=0, dx=5, dy=5, width=.5, color = "purple") 


plt.arrow(x=0, y=0, dx=10, dy=0, width=.5, color = (0,0,1), length_includes_head=True) 
plt.arrow(x=0, y=0, dx=0, dy=10, width=.5, color = (1,0,0), length_includes_head=True) 

# plt.arrow(x=0, y=0, dx=5, dy=5, width=.5, color = (.5, 0, .5)) 
# plt.arrow(x=0, y=0, dx=7.5, dy=2.5, width=.5, color = (.25, 0, .75)) 
# plt.arrow(x=0, y=0, dx=2.5, dy=7.5, width=.5, color = (.75, 0, .25)) 


plt.savefig("just_two_vectors.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Examples

# %%
plt.figure(figsize = (5,5))

if 1:
    fig = plt.figure(1)
    ax = SubplotZero(fig, 111)
    fig.add_subplot(ax)

    for direction in ["xzero", "yzero"]:
        ax.axis[direction].set_axisline_style("-|>")
        ax.axis[direction].set_visible(True)

    for direction in ["left", "right", "bottom", "top"]:
        ax.axis[direction].set_visible(False)

    #x = np.linspace(-0.5, 1., 100)
    #ax.plot(x, np.sin(x*np.pi))

plt.xlim([-1, 25])
plt.ylim([-1, 25])

# plt.arrow(x=0, y=0, dx=5, dy=0, width=.5, color = "blue") 
# plt.arrow(x=0, y=0, dx=0, dy=5, width=.5, color = "red") 

# plt.arrow(x=0, y=0, dx=5, dy=5, width=.5, color = "purple") 


plt.arrow(x=0, y=0, dx=10, dy=0, width=.5, color = (0,0,1), length_includes_head=True) 
plt.arrow(x=0, y=0, dx=0, dy=10, width=.5, color = (1,0,0), length_includes_head=True) 

plt.arrow(x=0, y=0, dx=10, dy=10, width=.5, color = (.5, 0, .5), length_includes_head=True) 
# plt.arrow(x=0, y=0, dx=7.5, dy=2.5, width=.5, color = (.25, 0, .75), length_includes_head=True) 
# plt.arrow(x=0, y=0, dx=2.5, dy=7.5, width=.5, color = (.75, 0, .25), length_includes_head=True) 


plt.savefig("example_vector_1.png", bbox_inches = "tight")
plt.show()

# %%
plt.figure(figsize = (5,5))

if 1:
    fig = plt.figure(1)
    ax = SubplotZero(fig, 111)
    fig.add_subplot(ax)

    for direction in ["xzero", "yzero"]:
        ax.axis[direction].set_axisline_style("-|>")
        ax.axis[direction].set_visible(True)

    for direction in ["left", "right", "bottom", "top"]:
        ax.axis[direction].set_visible(False)

    #x = np.linspace(-0.5, 1., 100)
    #ax.plot(x, np.sin(x*np.pi))

plt.xlim([-1, 25])
plt.ylim([-1, 25])

# plt.arrow(x=0, y=0, dx=5, dy=0, width=.5, color = "blue") 
# plt.arrow(x=0, y=0, dx=0, dy=5, width=.5, color = "red") 

# plt.arrow(x=0, y=0, dx=5, dy=5, width=.5, color = "purple") 


plt.arrow(x=0, y=0, dx=10, dy=0, width=.5, color = (0,0,1), length_includes_head=True) 
plt.arrow(x=0, y=0, dx=0, dy=10, width=.5, color = (1,0,0), length_includes_head=True) 

# plt.arrow(x=0, y=0, dx=10, dy=10, width=.5, color = (.5, 0, .5), length_includes_head=True) 
plt.arrow(x=0, y=0, dx=15, dy=5, width=.5, color = (.25, 0, .75), length_includes_head=True) 
# plt.arrow(x=0, y=0, dx=2.5, dy=7.5, width=.5, color = (.75, 0, .25), length_includes_head=True) 


plt.savefig("example_vector_2.png", bbox_inches = "tight")
plt.show()

# %%
plt.figure(figsize = (5,5))

if 1:
    fig = plt.figure(1)
    ax = SubplotZero(fig, 111)
    fig.add_subplot(ax)

    for direction in ["xzero", "yzero"]:
        ax.axis[direction].set_axisline_style("-|>")
        ax.axis[direction].set_visible(True)

    for direction in ["left", "right", "bottom", "top"]:
        ax.axis[direction].set_visible(False)

    #x = np.linspace(-0.5, 1., 100)
    #ax.plot(x, np.sin(x*np.pi))

plt.xlim([-1, 25])
plt.ylim([-1, 25])

# plt.arrow(x=0, y=0, dx=5, dy=0, width=.5, color = "blue") 
# plt.arrow(x=0, y=0, dx=0, dy=5, width=.5, color = "red") 

# plt.arrow(x=0, y=0, dx=5, dy=5, width=.5, color = "purple") 


plt.arrow(x=0, y=0, dx=10, dy=0, width=.5, color = (0,0,1), length_includes_head=True) 
plt.arrow(x=0, y=0, dx=0, dy=10, width=.5, color = (1,0,0), length_includes_head=True) 

# plt.arrow(x=0, y=0, dx=10, dy=10, width=.5, color = (.5, 0, .5), length_includes_head=True) 
# plt.arrow(x=0, y=0, dx=15, dy=5, width=.5, color = (.25, 0, .75), length_includes_head=True) 
plt.arrow(x=0, y=0, dx=5, dy=15, width=.5, color = (.75, 0, .25), length_includes_head=True) 


plt.savefig("example_vector_3.png", bbox_inches = "tight")
plt.show()

# %%
if 1:
    fig = plt.figure(1)
    ax = SubplotZero(fig, 111)
    fig.add_subplot(ax)

    for direction in ["xzero", "yzero"]:
        ax.axis[direction].set_axisline_style("-|>")
        ax.axis[direction].set_visible(True)

    for direction in ["left", "right", "bottom", "top"]:
        ax.axis[direction].set_visible(False)

    # x = np.linspace(0, 50, 100)
    # ax.plot(x, 10+x-x, color = "black", linestyle = "--")

plt.xlim([-1, 50])
plt.ylim([-1, 25])



plt.arrow(x=0, y=0, dx=10, dy=0, width=.5, color = (0,0,1), length_includes_head=True) 
plt.arrow(x=0, y=0, dx=0, dy=10, width=.5, color = (1,0,0), length_includes_head=True) 
#plt.quiver(0,0, 50, 30, color = (1,0,0), scale = .0000)


for i in range(1,10):
    for j in range(1,6):
        plt.arrow(x=0, y=0, dx=5*i, dy=5*j, width=.5, color = lc_color(i,j), length_includes_head=True)
    



plt.savefig("many_more_examples.png", bbox_inches = "tight")
plt.show()
